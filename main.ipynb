# %%
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('test image/image.jpg')
# OpenCV opens images as BRG  
# but we want it as RGB and  
# we also need a grayscale  
# version

img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)


f, ax = plt.subplots(1,2,figsize = (10,6))
ax = ax.flatten()
ax[0].imshow(img_rgb)
ax[0].set_title('rgb image',size=20)
ax[1].imshow(img_gray)
ax[1].set_title('gray image',size=20)
plt.show()

# %%
# Use minSize because for not  
# bothering with extra-small  
# dots that would look like STOP signs 
stop_data = cv2.CascadeClassifier('test image/stop_data.xml') 
  
found = stop_data.detectMultiScale(img_gray,  
                                   minSize =(20,20)) 
  
# Don't do anything if there's  
# no sign 
amount_found = len(found) 
  
if amount_found != 0: 
      
    # There may be more than one 
    # sign in the image 
    for (x, y, width, height) in found: 
          
        # We draw a green rectangle around 
        # every recognized sign 
        cv2.rectangle(img_rgb, (x, y),  
                      (x + height, y + width),  
                      (0, 255, 3),6) 
          
# Creates the environment of  
# the picture and shows it 
plt.imshow(img_rgb) 
plt.show()

# %%
found
# Out:
# array([[144,  66, 315, 315]], dtype=int32)
